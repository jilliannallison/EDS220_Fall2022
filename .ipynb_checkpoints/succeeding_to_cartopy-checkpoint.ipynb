# %%
import netCDF4 as nc
import numpy as np
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs

# %%
precip = nc.Dataset("/Users/jilliannallison/eds-220/EDS220_Fall2022/precip_data.nc")

# %%
precip.variables
# Out:
# OrderedDict([('longitude',
#               <class 'netCDF4._netCDF4.Variable'>
#               float32 longitude(longitude)
#                   units: degrees_east
#                   long_name: longitude
#               unlimited dimensions:
#               current shape = (7,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('latitude',
#               <class 'netCDF4._netCDF4.Variable'>
#               float32 latitude(latitude)
#                   units: degrees_north
#                   long_name: latitude
#               unlimited dimensions:
#               current shape = (6,)
#               filling on, default _FillValue of 9.969209968386869e+36 used),
#              ('time',
#               <class 'netCDF4._netCDF4.Variable'>
#               int32 time(time)
#                   units: hours since 1900-01-01 00:00:00.0
#                   long_name: time
#                   calendar: gregorian
#               unlimited dimensions:
#               current shape = (24,)
#               filling on, default _FillValue of -2147483647 used),
#              ('tp',
#               <class 'netCDF4._netCDF4.Variable'>
#               int16 tp(time, latitude, longitude)
#                   scale_factor: 1.3899898117214682e-07
#                   add_offset: 0.004562546848776015
#                   _FillValue: -32767
#                   missing_value: -32767
#                   units: m
#                   long_name: Total precipitation
#               unlimited dimensions:
#               current shape = (24, 6, 7)
#               filling on)])

# %%
precip
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     Conventions: CF-1.6
#     history: 2022-11-04 02:33:08 GMT by grib_to_netcdf-2.25.1: /opt/ecmwf/mars-client/bin/grib_to_netcdf.bin -S param -o /cache/data4/adaptor.mars.internal-1667529188.2819111-24014-2-31eda61d-58c5-492a-82cc-4edb395689ca.nc /cache/tmp/31eda61d-58c5-492a-82cc-4edb395689ca-adaptor.mars.internal-1667529185.6998148-24014-3-tmp.grib
#     dimensions(sizes): longitude(7), latitude(6), time(24)
#     variables(dimensions): float32 longitude(longitude), float32 latitude(latitude), int32 time(time), int16 tp(time,latitude,longitude)
#     groups:

# %%
time = precip.variables['time']
lon = precip.variables['longitude']
lat = precip.variables['latitude']
data = precip.variables['tp']


time = nc.num2date(precip.variables['time'][:],
                    units='milliseconds since 1970-01-01T00:00:00')
# Out:
# /tmp/ipykernel_3040724/2066524841.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   time = nc.num2date(precip.variables['time'][:],

# %%
lon2d, lat2d = np.meshgrid(lon, lat)

# %%
plt.figure()
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([-121.25,-122.75,36.75,38])
ax.coastlines()
# Add coloring for ocean
ax.add_feature(cartopy.feature.OCEAN)
# Add coloring for land
ax.add_feature(cartopy.feature.LAND)
ax.contourf(lon2d, lat2d, data, cmap = "jet")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [21], line 9
#       7 # Add coloring for land
#       8 ax.add_feature(cartopy.feature.LAND)
# ----> 9 ax.contourf(lon2d, lat2d, data, cmap = "jet")
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:318, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     313     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     314                      'is not supported - consider using '
#     315                      'PlateCarree/RotatedPole.')
#     317 kwargs['transform'] = transform
# --> 318 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:362, in _add_transform_first.<locals>.wrapper(self, *args, **kwargs)
#     360     # Use the new points as the input arguments
#     361     args = (x, y, z) + args[3:]
# --> 362 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:1662, in GeoAxes.contourf(self, *args, **kwargs)
#    1659             if not hasattr(sub_trans, 'force_path_ccw'):
#    1660                 sub_trans.force_path_ccw = True
# -> 1662 result = super().contourf(*args, **kwargs)
#    1664 # We need to compute the dataLim correctly for contours.
#    1665 bboxes = [col.get_datalim(self.transData)
#    1666           for col in result.collections
#    1667           if col.get_paths()]
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6384, in Axes.contourf(self, *args, **kwargs)
#    6375 """
#    6376 Plot filled contours.
#    6377
#    (...)
#    6381 %(contour_doc)s
#    6382 """
#    6383 kwargs['filled'] = True
# -> 6384 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6385 self._request_autoscale_view()
#    6386 return contours
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/contour.py:794, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     790 if self.negative_linestyles is None:
#     791     self.negative_linestyles = \
#     792         mpl.rcParams['contour.negative_linestyle']
# --> 794 kwargs = self._process_args(*args, **kwargs)
#     795 self._process_levels()
#     797 self._extend_min = self.extend in ['min', 'both']
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/contour.py:1435, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1432         corner_mask = mpl.rcParams['contour.corner_mask']
#    1433 self._corner_mask = corner_mask
# -> 1435 x, y, z = self._contour_args(args, kwargs)
#    1437 contour_generator = contourpy.contour_generator(
#    1438     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1439     line_type=contourpy.LineType.SeparateCode,
#    1440     fill_type=contourpy.FillType.OuterCode,
#    1441     chunk_size=self.nchunk)
#    1443 t = self.get_transform()
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/contour.py:1473, in QuadContourSet._contour_args(self, args, kwargs)
#    1471     args = args[1:]
#    1472 elif Nargs <= 4:
# -> 1473     x, y, z = self._check_xyz(args[:3], kwargs)
#    1474     args = args[3:]
#    1475 else:
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/matplotlib/contour.py:1498, in QuadContourSet._check_xyz(self, args, kwargs)
#    1496 x = np.asarray(x, dtype=np.float64)
#    1497 y = np.asarray(y, dtype=np.float64)
# -> 1498 z = ma.asarray(args[2], dtype=np.float64)
#    1500 if z.ndim != 2:
#    1501     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/numpy/ma/core.py:8003, in asarray(a, dtype, order)
#    7959 """
#    7960 Convert the input to a masked array of the given data-type.
#    7961
#    (...)
#    8000
#    8001 """
#    8002 order = order or 'C'
# -> 8003 return masked_array(a, dtype=dtype, copy=False, keep_mask=True,
#    8004                     subok=False, order=order)
#
# File /opt/anaconda3/envs/carto/lib/python3.8/site-packages/numpy/ma/core.py:2826, in MaskedArray.__new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2817 """
#    2818 Create a new masked array from scratch.
#    2819
#    (...)
#    2823
#    2824 """
#    2825 # Process data.
# -> 2826 _data = np.array(data, dtype=dtype, copy=copy,
#    2827                  order=order, subok=True, ndmin=ndmin)
#    2828 _baseclass = getattr(data, '_baseclass', type(_data))
#    2829 # Check that we're not erasing the mask.
#
# TypeError: __array__() takes no arguments (1 given)
